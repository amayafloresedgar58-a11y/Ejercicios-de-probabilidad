# %% [markdown]
# <a href="https://colab.research.google.com/github/amayafloresedgar58-a11y/Ejercicios-de-probabilidad/blob/main/ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy

def area(radio):
    return sympy.pi * (radio ** 2)

# %%
area(10)

# %%
def area_numerco(radio):
  return 3.1416 * (radio ** 2)

# %%
area_numerco(5)

# %%
import random

moneda_lados = ["aguila", "sol"]

def lanzar_moneda():
    return random.choice(moneda_lados)

lanzar_moneda()

# %%
import random

dado_caras = ["cara 1", "cara 2", "cara 3", "cara 4", "cara 5", "cara 6"]

def lanzar_dado():
    return random.choice(dado_caras)

lanzar_dado()
